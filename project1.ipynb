# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('iris.csv')
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %% [markdown]
# 1A: There are 5 columns in the file. The data types are floating point value and string. The first column name is Sepal.Length which describes a flower's length of sepal. The second column name is Sepal.Width which describes a flower's width of sepal. THe third column name is Petal.Length which describes a flower's length of petal. The fourth column name is Petal.Width which describes a flower's width of petal. THe last column name is Species whcih shows the flower's species. All in all, the five columns give us a idea of the flower'species, length and width of both sepal and petal.

# %% [markdown]
# 1B: There are 150 rows in the data.

# %%
group = data[ ['Species']]. groupby('Species')
group.head(1)
# Out:
#         Species
# 0        setosa
# 50   versicolor
# 100   virginica

# %% [markdown]
# 1C: There are 3 species are included in this data set which are setosa,versicolor and virginica.

# %%
data.loc[34]
# Out:
# Sepal.Length       4.9
# Sepal.Width        3.1
# Petal.Length       1.5
# Petal.Width        0.1
# Species         setosa
# Name: 34, dtype: object

# %%
data.loc[34,'Petal.Width'] = 0.2
data.loc[34]
# Out:
# Sepal.Length       4.9
# Sepal.Width        3.1
# Petal.Length       1.5
# Petal.Width        0.2
# Species         setosa
# Name: 34, dtype: object

# %%
data.loc[37]
# Out:
# Sepal.Length       4.9
# Sepal.Width        3.1
# Petal.Length       1.5
# Petal.Width        0.1
# Species         setosa
# Name: 37, dtype: object

# %%
data.loc[37,'Sepal.Width']=3.6
data.loc[37,'Petal.Length']=1.4
data.loc[37]
# Out:
# Sepal.Length       4.9
# Sepal.Width        3.6
# Petal.Length       1.4
# Petal.Width        0.1
# Species         setosa
# Name: 37, dtype: object

# %%
data['Petal ratio'] = None

data['Sepal ratio'] = None

data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
data['Petal ratio']= data['Petal.Length'] / data['Petal.Width']
data['Sepal ratio']= data['Sepal.Length']/ data['Sepal.Width']
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
group = data.groupby(['Species'])
group['Petal ratio'].describe()
# Out:
#             count      mean       std       min       25%       50%       75%  \
# Species
# setosa       50.0  6.908000  2.854545  2.666667  4.687500  7.000000  7.500000
# versicolor   50.0  3.242837  0.312456  2.666667  3.016667  3.240385  3.417582
# virginica    50.0  2.780662  0.407367  2.125000  2.511364  2.666667  3.055556
#
#              max
# Species
# setosa      15.0
# versicolor   4.1
# virginica    4.0

# %%
group['Sepal ratio'].describe()
# Out:
#             count      mean       std       min       25%       50%       75%  \
# Species
# setosa       50.0  1.470188  0.118750  1.268293  1.385684  1.463063  1.541444
# versicolor   50.0  2.160402  0.228658  1.764706  2.033929  2.161290  2.232692
# virginica    50.0  2.230453  0.246992  1.823529  2.031771  2.169540  2.342949
#
#                  max
# Species
# setosa      1.956522
# versicolor  2.818182
# virginica   2.961538
